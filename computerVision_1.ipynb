# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Lenovo\anaconda3\python.exe

# %%
import sys
# !{sys.executable} -m pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.2/12.3 MB 3.1 MB/s eta 0:00:04
#    - -------------------------------------- 0.3/12.3 MB 3.6 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/12.3 MB 3.1 MB/s eta 0:00:04
#    -- ------------------------------------- 0.8/12.3 MB 4.1 MB/s eta 0:00:03
#    --- ------------------------------------ 1.1/12.3 MB 4.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.4/12.3 MB 4.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/12.3 MB 5.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.8/12.3 MB 4.9 MB/s eta 0:00:03
#    ------ --------------------------------- 2.0/12.3 MB 4.7 MB/s eta 0:00:03
# ...

# %%
import cv2
import numpy as np

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.13.0

# %%
img = cv2.imread("img1.jpg")
re_img = cv2.resize(img,(500,500))
cv2.imshow("sid",re_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("img1.jpg")
re_img = cv2.resize(img,(500,500))
txt = cv2.putText(img = re_img,
                  text = "siddharth",
                  org = (60,430),
                  fontFace= cv2.FONT_HERSHEY_COMPLEX,
                  fontScale = 1,
                  color = (255,0,0),
                  thickness = 2,
                  lineType = cv2.LINE_4,
                  bottomLeftOrigin = False)

cv2.imshow("sid",txt)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
old_img = cv2.imread("img1.jpg")
old_img = cv2.resize(old_img,(500,500))

new_img = cv2.line(img = old_img,
                   pt1 = (150,160),
                   pt2 = (370,160),
                   color = (0,255,0),
                   thickness = 4,
                   lineType = cv2.LINE_8)

cv2.imshow("sid",new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
old_img = cv2.imread("img1.jpg")
old_img = cv2.resize(old_img,(500,500))

new_img = cv2.rectangle(img = old_img,
                   pt1 = (100,50),
                   pt2 = (400,350),
                   color = (0,255,0),
                   thickness = 4,
                   lineType = cv2.LINE_8)

cv2.imshow("sid",new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
old_img = cv2.imread("img1.jpg")
old_img = cv2.resize(old_img,(500,500))

new_img = cv2.circle(img = old_img,
                   center = (265,190),
                   radius = 160,
                   color = (0,255,0),
                   thickness = 4,
                   lineType = cv2.LINE_8)

cv2.imshow("sid",new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
old_img = cv2.imread("img1.jpg")
old_img = cv2.resize(old_img,(500,500))

old_img = cv2.putText(img = old_img,
                      text = "siddharth",
                      org = (350,65),
                      fontScale = 1,
                      fontFace = cv2.FONT_HERSHEY_DUPLEX,
                      color = (0,0,255),
                      thickness = 2,
                      lineType = cv2.LINE_4,
                      bottomLeftOrigin = False)
new_img = cv2.ellipse(img = old_img,
                   center = (265,190),
                   axes = (140,200),
                   angle = 30,
                   startAngle = -60,
                   endAngle = 280,
                   color = (0,255,0),
                   thickness = 4,
                   lineType = cv2.LINE_8)

cv2.imshow("sid",new_img)
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
old_img = cv2.imread("img1.jpg")
old_img = cv2.resize(old_img,(500,500))

new_img = cv2.polylines(img = old_img,
                   pts = [np.array([[100,100],[250,35],[420,100],[420,350],[100,350]])],
                   isClosed = True,
                   color = (0,255,0),
                   thickness = 4,
                   lineType = cv2.LINE_8)

cv2.imshow("sid",new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1 = cv2.imread("img1.jpg")
img2 = cv2.imread("img2.jpg") 

img1 = cv2.resize(img1,(500,500))
img2 = cv2.resize(img2,(500,500))

new_img = cv2.addWeighted(img1,0.5,img2,1,1)

cv2.imshow("sid",new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1 = cv2.imread("img1.jpg")
img2 = cv2.imread("img2.jpg") 

img1 = cv2.resize(img1,(500,500))
img2 = cv2.resize(img2,(500,500))

#new_img = cv2.bitwise_and(img1,img2)
#new_img = cv2.bitwise_or(img1,img2)
new_img = cv2.bitwise_xor(img1,img2)
#new_img = cv2.bitwise_not(img1)

h = np.hstack((img1,img2,new_img)) 

cv2.imshow("sid",h)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("img1.jpg")
img = cv2.resize(img,(500,500))

new_img = cv2.Canny(img,200,200,apertureSize = 5,L2gradient = True)

    
cv2.imshow("sid",new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("img1.jpg")
new_img = cv2.resize(img,(500,500))

#w,h = new_img.shape[0],new_img.shape[1]
m = cv2.getRotationMatrix2D((250,250),40,1)
n_img = cv2.warpAffine(new_img,m,(500,500))

cv2.imshow("sid",n_img) 
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("image.jpg")
img = cv2.resize(img,(500,500))

#g = cv2.GaussianBlur(img,(9,9),0)
#g = cv2.medianBlur(img,5)
g = cv2.bilateralFilter(img,9,75,75)
h = np.hstack((img,g))
cv2.imshow("sid",h)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# %%
img = cv2.imread("image.jpg")
res_img = cv2.resize(img,(300,300))

img = cv2.copyMakeBorder(res_img,20,20,20,20,cv2.BORDER_CONSTANT,value = 2)
img = cv2.resize(img,(300,300))
h = np.hstack((res_img,img))

cv2.imshow("sid",h)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# play a video using openCV

# %%
import cv2
cap = cv2.VideoCapture("video1.mp4")
while cap.isOpened():
    r,frame = cap.read()
    if r ==True:
        frame = cv2.resize(frame,(500,500))
        cv2.imshow("sid",frame)
        if cv2.waitKey(25) & 0xff == ord("p"):
            pass
    else:
        break
cap.release()
cv2.destroyAllWindows()

# %%
import cv2

cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Camera not opened")
else:
    print("Camera opened")

while True:
    ret, frame = cap.read()
    
    if not ret:
        print("Frame not received")
        break
        
    cv2.imshow("Webcam", frame)
    
    if cv2.waitKey(25) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Camera opened

# %%
img = cv2.imread("image.jpg")
img = cv2.resize(img,(1000,1000))
print(img.shape)

new_img = cv2.pyrDown(img)
print(new_img.shape)

new_img1 = cv2.pyrDown(new_img)
print(new_img1.shape)

new_img2 = cv2.pyrDown(new_img1)
print(new_img2.shape)

cv2.imshow("sid",new_img)
cv2.imshow("sid1",new_img1)
cv2.imshow("sid2",new_img2)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (1000, 1000, 3)
# (500, 500, 3)
# (250, 250, 3)
# (125, 125, 3)

# %%
import cv2
import numpy as np

# %%
img = cv2.imread("image.jpg")
img = cv2.resize(img,(500,500))

m = np.float32([[1,0,100],[0,1,50]])
new = cv2.warpAffine(img,m,(500,500))

h = np.hstack((img,new))

cv2.imshow("sid",h)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("image.jpg")
img = cv2.resize(img,(500,500))

pts1 = np.float32([[200,0],[500,0],[0,500],[500,500]])
pts2 = np.float32([[0,0],[400,50],[50,400],[450,450]])

matrix = cv2.getPerspectiveTransform(pts1, pts2)

new = cv2.warpPerspective(img, matrix, (500,500))

h = np.hstack((img,new))

cv2.imshow("sid",h)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np 
import cv2

# %%
import cv2
cap = cv2.VideoCapture("video2.mp4")
while cap.isOpened():
    r , frame = cap.read()
    if r == True:
        frame = cv2.resize(frame,(600,500))
        cv2.imshow("sid",frame)
        if cv2.waitKey(25) & 0xff == ord("q"):
            break
    else:
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2

cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("camera not opened")
else:
    print("camera opened")

while True:
    r ,frame = cap.read()
    
    if not r :
        print("frame not recived")
        break
        
    cv2.imshow("sid",frame)
        
    if cv2.waitKey(25) & 0xff == ord("q"):
        break


cap.release()
cv2.destroyAllWindows()
# Out:
# camera opened

# %%
org_v = cv2.VideoCapture("video2.mp4")
org_m = cv2.createBackgroundSubtractorMOG2()

while True:
    r,frame = org_v.read()
    if r == True:
        frame = cv2.resize(frame,(700,500))
        sub_v = org_m.apply(frame)
        cv2.imshow("sub_org",sub_v)
        cv2.imshow("sid_org",frame)
        if cv2.waitKey(25) & 0xff == ord("p"):
            break
    else:
        break

org_v.release()
cv2.destroyAllWindows()

# %%
img = cv2.imread("image.jpg")
img = cv2.resize(img,(500,500))

new = cv2.cvtColor(img,cv2.COLOR_BGR2XYZ)
cv2.imshow("sid",new)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# %%
cap = cv2.VideoCapture(0)
c = 0
while True:
    r , frame = cap.read()
    if r == True:
        frame = cv2.resize(frame,(500,500))
        filename = r"C://Users//Lenovo//extractVideoToImage//images//ord_img" + str(c) + ".png"
        cv2.imwrite(filename,frame)
        cv2.imshow("sid",frame)
        c = c+1
        if cv2.waitKey(1) & 0xff == ord("p"):
            break
    else:
        break

cap.release()
cv2.destroyAllWindows()

# %%
img = cv2.imread("image.jpg")
img = cv2.resize(img,(500,500))
print(img.shape)

crop = img[90:320,140:350]

cv2.imshow("Crop",crop)
cv2.imshow("sid",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (500, 500, 3)

# %%
blank_b = np.zeros((500,500,3),np.uint8)*255
cv2.imshow("sid",blank_b)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("image.jpg")
img = cv2.resize(img,(500,500))

#img = cv2.rotate(img,cv2.ROTATE_90_COUNTERCLOCKWISE)
img = cv2.transpose(img)

cv2.imshow("sid",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)
f = cv2.VideoWriter_fourcc(*"XVID")
out = cv2.VideoWriter("demo.mp4",f,40,(640,480))
while True:
    r , frame = cap.read()
    if r == True:
        frame = cv2.flip(frame,1)
        cv2.imshow("sid",frame)
        out.write(frame)
        if cv2.waitKey(1) & 0xff == ord("p"):
            break
    else:
        break

cap.release()
out.release()
cv2.destroyAllWindows()

# %%
img = cv2.imread("image.jpg")

cv2.circle(img,(130,90),4,(0,0,255),-1)
cv2.circle(img,(340,80),4,(0,0,255),-1)
cv2.circle(img,(130,290),4,(0,0,255),-1)
cv2.circle(img,(340,290),4,(0,0,255),-1)

w,h = (500,600)
src1 = np.float32([[130,90],[340,80],[130,290],[340,290]])
dst1 = np.float32([[0,0],[w,0],[0,h],[w,h]])

m = cv2.getPerspectiveTransform(src1,dst1)
new_img = cv2.warpPerspectiver(img,m,(w,h))

cv2.imshow("new",new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img = cv2.imread("image.jpg")
img = cv2.resize(img,(500,500))
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(5,4))
hist = cv2.calcHist([img],[0],None,[255],[0,255])
plt.plot(hist)
plt.show()
#_,th = cv2.threshold(img,100,255,cv2.THRESH_BINARY)
_,th = cv2.threshold(img,90,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

cv2.imshow("sikkkd",th)
cv2.imshow("sid",img)
cv2.imwrite("sibdjbd.png",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.figure(figsize=(6,3))
black = np.zeros((500,500,3),np.uint8)*255
white = np.ones((500,500,3),np.uint8)*255


hist = cv2.calcHist([black],[0],None,[256],[0,256])
hist1 = cv2.calcHist([white],[0],None,[256],[0,256])
plt.plot(hist),
plt.plot(hist1)
plt.show()

cv2.imshow("black",black)
cv2.imshow("white",white)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("image.jpg")
img = cv2.resize(img,(300,300))

b,g,r = cv2.split(img)

hist_b = cv2.calcHist([b],[0],None,[256],[0,256])
hist_g = cv2.calcHist([g],[0],None,[256],[0,256])
hist_r = cv2.calcHist([r],[0],None,[256],[0,256])

plt.subplot(3,1,1)
plt.plot(hist_b)

plt.subplot(3,1,2)
plt.plot(hist_g)

plt.subplot(3,1,3)
plt.plot(hist_r)
plt.show()

cv2.imshow("sid",img)
cv2.imshow("b",b)
cv2.imshow("g",g)
cv2.imshow("r",r)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("image.jpg")
img = cv2.resize(img,(300,300))

b,g,r = cv2.split(img)

plt.hist(b.ravel(),255,(0,255),color = "blue")
plt.hist(g.ravel(),255,(0,255),color = "green")
plt.hist(r.ravel(),255,(0,255),color = "red")

plt.show()

cv2.imshow("sid",img)
cv2.imshow("b",b)
cv2.imshow("g",g)
cv2.imshow("r",r)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_3920\806186072.py:6: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(b.ravel(),255,(0,255),color = "blue")
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_3920\806186072.py:7: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(g.ravel(),255,(0,255),color = "green")
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_3920\806186072.py:8: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(r.ravel(),255,(0,255),color = "red")

# %%
img = cv2.imread("image.jpg")
img = cv2.resize(img,(300,300))
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
hist = cv2.calcHist([img],[0],None,[255],[0,255])

equ = cv2.equalizeHist(img)
hist1 = cv2.calcHist([img],[0],None,[255],[0,255])

cl = cv2.createCLAHE(clipLimit = 0, tileGridSize = (8,8))
f = cl.apply(img)

plt.figure(figsize=(5,4))
plt.plot(hist)
plt.plot(hist1,color = "red")
plt.plot(f,c="green")
plt.show()

cv2.imshow("img",img)
cv2.imshow("equ",equ)
cv2.imshow("f",f)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def python(event,x,y,f,p):
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(img,(x,y),5,(0,0,255),4)
    elif event == cv2.EVENT_RBUTTONDOWN:
        cv2.rectangle(img,(x,y),(x+20,y+20),(255,0,0),4)

cv2.namedWindow("siddharth")
img = np.ones((500,500,3),np.uint8)*255
cv2.setMouseCallback("siddharth",python)
while True:
    cv2.imshow("siddharth",img)
    if cv2.waitKey(25) & 0xff == ord("p"):
        break

cv2.destroyAllWindows()

# %%
img = cv2.imread("unnamed.png")
img = cv2.resize(img,(500,500))
img1 = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

r,thr = cv2.threshold(img1,200,255,cv2.THRESH_BINARY)
c,h = cv2.findContours(thr,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)

new = cv2.drawContours(img,c,-1,(255,0,0),2)

cv2.imshow("sid1",new)
cv2.imshow("sid",thr)
cv2.imshow("sidharth",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# %%
import cv2
def nothing(x):
    pass
    
cv2.namedWindow("siddharth")
cv2.createTrackbar("th","siddharth",0,255,nothing)

cv2.createTrackbar("lb","siddharth",0,255,nothing)
cv2.createTrackbar("lg","siddharth",0,255,nothing)
cv2.createTrackbar("lr","siddharth",0,255,nothing)

cv2.createTrackbar("hb","siddharth",255,255,nothing)
cv2.createTrackbar("hg","siddharth",255,255,nothing)
cv2.createTrackbar("hr","siddharth",255,255,nothing)

cap = cv2.VideoCapture(0)
while cap.isOpened():
    r,frame = cap.read()
    if r==True:
        frame = cv2.resize(frame,(400,400))
        thr = cv2.getTrackbarPos("th","siddharth")
        LB = cv2.getTrackbarPos("lb","siddharth")
        LG = cv2.getTrackbarPos("lg","siddharth")
        LR = cv2.getTrackbarPos("lr","siddharth")

        HB = cv2.getTrackbarPos("hb","siddharth")
        HG = cv2.getTrackbarPos("hg","siddharth")
        HR = cv2.getTrackbarPos("hr","siddharth")

        lower = np.array([LB,LG,LR])
        upper = np.array([HB,HG,HR])

        frame = cv2.flip(frame,1)
        hsv = cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
        
        m = cv2.inRange(hsv,lower,upper)
        res = cv2.bitwise_and(frame,frame,mask=m)
        fr = cv2.bitwise_not(res)

        re,thi = cv2.threshold(m,thr,255,cv2.THRESH_BINARY)
        c,h = cv2.findContours(thi,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
        cv2.drawContours(frame,c,-1,(255,0,0),2)

        cv2.imshow("thr",thi)
        cv2.imshow("res",res)
        cv2.imshow("mask",m  )
        cv2.imshow("sid",frame)
        if cv2.waitKey(25) & 0xff == ord("p"):
            break
    else:
        break

cap.release()
cv2.destroyAllWindows()
